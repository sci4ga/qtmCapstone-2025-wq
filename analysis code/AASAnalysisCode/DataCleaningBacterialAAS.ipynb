# %%
import pandas as pd
import numpy as np

# %%
bacterialData = pd.read_csv("/Users/keerthyrangan/Downloads/bacteria(Sheet1).csv", encoding = "latin-1")
bacterialData
# Out:
# /var/folders/l4/kpydl4ws7zd8nz43jqjhct5r0000gn/T/ipykernel_33797/2602944678.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   bacterialData = pd.read_csv("/Users/keerthyrangan/Downloads/bacteria(Sheet1).csv", encoding = "latin-1")
#        EventID          EventDate  GroupID  \
# 0          770   3/18/96 12:00 PM      245
# 1          763   5/14/96 12:00 PM      245
# 2          653   3/23/98 12:00 PM      208
# 3          655   3/24/98 12:00 PM      208
# 4          657   3/25/98 12:00 PM      208
# ...        ...                ...      ...
# 46315    99134   12/25/22 4:30 PM     2753
# 46316    99140  12/26/22 10:25 AM     1906
# 46317    99141  12/26/22 10:55 AM     1906
# 46318    99135   12/26/22 1:15 PM     3028
# 46319    99136   12/26/22 4:28 PM     1461
#
#                                            GroupName  SiteID  \
# 0                                  Salem High School     141
# 1                                  Salem High School     141
# 2           Waterford Place Condominium Assoc., Inc.     129
# 3           Waterford Place Condominium Assoc., Inc.     129
# 4           Waterford Place Condominium Assoc., Inc.     129
# ...                                              ...     ...
# 46315                            Gram's Collins Gals    5482
# 46316                  Satilla Riverkeeper & Friends    7388
# 46317                  Satilla Riverkeeper & Friends    3431
# 46318                               SCFP Stream Team    7364
# 46319  Keep Smyrna Beautiful Adopt-A-Stream (KSBAAS)    7363
#
#                                                SiteName  site_latitude  \
# 0                                       Snapping Shoals        33.5936
# 1                                       Snapping Shoals        33.5936
# 2                                          Poplar Creek        33.8976
# 3                                          Poplar Creek        33.8976
# 4                                          Poplar Creek        33.8976
# ...                                                 ...            ...
# 46315  Creek between Chimney Springs and Creekstone Way        34.0078
# 46316                                Hacklebarney Creek        31.2720
# 46317                                 Jamestown Landing        31.2983
# 46318                                    Cambarus Creek        34.1485
# 46319                                      Poplar Creek        33.8769
#
#        site_longitude  site_altitude  bact_detail_rid  ...  hold_end_datetime  \
# 0            -83.9852     228.927612             1753  ...                NaN
# 1            -83.9852     228.927612             1751  ...                NaN
# 2            -84.4759     274.621826            18335  ...                NaN
# 3            -84.4759     274.621826            17691  ...                NaN
# 4            -84.4759     274.621826            17692  ...                NaN
# ...               ...            ...              ...  ...                ...
# 46315        -84.4114     272.980000            49847  ...                NaN
# 46316        -82.3131      41.700000            49853  ...                NaN
# 46317        -82.3924      29.910000            49854  ...                NaN
# 46318        -84.0427     339.140000            49848  ...                NaN
# 46319        -84.4991     296.780000            49849  ...                NaN
#
#        min_temp max_temp three_M_plate ecoli_idexx fecal_coliform  \
# 0           NaN      NaN             1         NaN          310.0
# 1           NaN      NaN             1         NaN         2750.0
# 2           NaN      NaN             1         NaN          -25.0
# 3           NaN      NaN             1         NaN          150.0
# 4           NaN      NaN             1         NaN           50.0
# ...         ...      ...           ...         ...            ...
# 46315       NaN      NaN             0         NaN            NaN
# 46316       NaN      NaN             0         NaN            NaN
# 46317       NaN      NaN             0         NaN            NaN
# 46318       NaN      NaN             0         NaN            NaN
# 46319       NaN      NaN             0         NaN            NaN
#
#        ecoli_other ecoli_other_unit comments warnings
# 0              NaN              NaN      NaN      NaN
# 1              NaN              NaN      NaN      NaN
# 2              NaN              NaN      NaN      NaN
# 3              NaN              NaN      NaN      NaN
# 4              NaN              NaN      NaN      NaN
# ...            ...              ...      ...      ...
# 46315          NaN              NaN      NaN      NaN
# 46316          NaN              NaN      NaN      NaN
# 46317          NaN              NaN      NaN      NaN
# 46318          NaN              NaN      NaN      NaN
# 46319          NaN              NaN      NaN      NaN
#
# [46320 rows x 29 columns]

# %%
bacterialData["EventDate"] = pd.to_datetime(bacterialData["EventDate"])

bacterialData = bacterialData[bacterialData["EventDate"].dt.year == 2022]
bacterialData
# Out:
# /var/folders/l4/kpydl4ws7zd8nz43jqjhct5r0000gn/T/ipykernel_33797/2943158998.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   bacterialData["EventDate"] = pd.to_datetime(bacterialData["EventDate"])
#        EventID           EventDate  GroupID  \
# 41180    92453 2022-01-01 13:00:00     3017
# 41181    92446 2022-01-01 16:30:00     1039
# 41182    92427 2022-01-03 09:40:00     2875
# 41183    95440 2022-01-03 17:12:00     2994
# 41184    98946 2022-01-05 07:30:00      458
# ...        ...                 ...      ...
# 46315    99134 2022-12-25 16:30:00     2753
# 46316    99140 2022-12-26 10:25:00     1906
# 46317    99141 2022-12-26 10:55:00     1906
# 46318    99135 2022-12-26 13:15:00     3028
# 46319    99136 2022-12-26 16:28:00     1461
#
#                                            GroupName  SiteID  \
# 41180                           Birdsong Subdivision    7342
# 41181                                Lakewood Colony     869
# 41182                                 Lake Sovereign    6866
# 41183                                 The Landa Band    7296
# 41184                      Chattahoochee Riverkeeper    6668
# ...                                              ...     ...
# 46315                            Gram's Collins Gals    5482
# 46316                  Satilla Riverkeeper & Friends    7388
# 46317                  Satilla Riverkeeper & Friends    3431
# 46318                               SCFP Stream Team    7364
# 46319  Keep Smyrna Beautiful Adopt-A-Stream (KSBAAS)    7363
#
#                                                SiteName  site_latitude  \
# 41180                       Cobbs Creek at Alverado Way        33.7484
# 41181        Detention pond on tributary of Rubes Creek        34.0561
# 41182                              Lake Sovereign - CHD        34.1628
# 41183         Powder Springs Creek at Still Family Farm        33.9042
# 41184                Linwood at Linwood Nature Preserve        34.3280
# ...                                                 ...            ...
# 46315  Creek between Chimney Springs and Creekstone Way        34.0078
# 46316                                Hacklebarney Creek        31.2720
# 46317                                 Jamestown Landing        31.2983
# 46318                                    Cambarus Creek        34.1485
# 46319                                      Poplar Creek        33.8769
#
#        site_longitude  site_altitude  bact_detail_rid  ...  hold_end_datetime  \
# 41180        -84.2546      275.44000            43565  ...            00:00.0
# 41181        -84.4971      283.80954            43562  ...            30:00.0
# 41182        -84.5329      273.27000            43547  ...            30:00.0
# 41183        -84.7194      288.39000            46164  ...                NaN
# 41184        -83.8515      339.18000            48765  ...                NaN
# ...               ...            ...              ...  ...                ...
# 46315        -84.4114      272.98000            49847  ...                NaN
# 46316        -82.3131       41.70000            49853  ...                NaN
# 46317        -82.3924       29.91000            49854  ...                NaN
# 46318        -84.0427      339.14000            49848  ...                NaN
# 46319        -84.4991      296.78000            49849  ...                NaN
#
#        min_temp max_temp three_M_plate ecoli_idexx fecal_coliform  \
# 41180      35.0     35.5             0         NaN            NaN
# 41181      34.6     35.8             0         NaN            NaN
# 41182      35.0     35.0             0         NaN            NaN
# 41183       NaN      NaN             0         NaN            NaN
# 41184       NaN      NaN             1       100.0            NaN
# ...         ...      ...           ...         ...            ...
# 46315       NaN      NaN             0         NaN            NaN
# 46316       NaN      NaN             0         NaN            NaN
# 46317       NaN      NaN             0         NaN            NaN
# 46318       NaN      NaN             0         NaN            NaN
# 46319       NaN      NaN             0         NaN            NaN
#
#        ecoli_other ecoli_other_unit comments warnings
# 41180          NaN              NaN      NaN      NaN
# 41181          NaN              NaN      NaN      NaN
# 41182          NaN              NaN      NaN      NaN
# 41183          NaN              NaN      NaN      NaN
# 41184          NaN              NaN      NaN      NaN
# ...            ...              ...      ...      ...
# 46315          NaN              NaN      NaN      NaN
# 46316          NaN              NaN      NaN      NaN
# 46317          NaN              NaN      NaN      NaN
# 46318          NaN              NaN      NaN      NaN
# 46319          NaN              NaN      NaN      NaN
#
# [5140 rows x 29 columns]

# %%
bacterialData = bacterialData[bacterialData["min_temp"] > 10]
bacterialData = bacterialData[bacterialData["min_temp"] < 49]
bacterialData = bacterialData[bacterialData["plate_blank"] == 0]

bacterialData
# Out:
#        EventID           EventDate  GroupID  \
# 41180    92453 2022-01-01 13:00:00     3017
# 41181    92446 2022-01-01 16:30:00     1039
# 41182    92427 2022-01-03 09:40:00     2875
# 41201    93453 2022-01-05 10:42:00     1087
# 41203    93452 2022-01-05 11:11:00     1087
# ...        ...                 ...      ...
# 46295    99052 2022-12-19 14:45:00     3014
# 46296    99053 2022-12-19 14:53:00     1501
# 46298    99116 2022-12-20 10:10:00     1618
# 46304    99120 2022-12-20 13:30:00     1727
# 46309    99119 2022-12-21 12:10:00     2845
#
#                                  GroupName  SiteID  \
# 41180                 Birdsong Subdivision    7342
# 41181                      Lakewood Colony     869
# 41182                       Lake Sovereign    6866
# 41201                 AAAS Stream Stompers     954
# 41203                 AAAS Stream Stompers     953
# ...                                    ...     ...
# 46295                Christine Brackenrich    7337
# 46296      Friends of Peachtree Hills Park    2033
# 46298  Upper Chattahoochee Trout Unlimited    2368
# 46304            WWALS_Watershed Coalition    6564
# 46309          Allatoona Creek Park Survey    6795
#
#                                          SiteName  site_latitude  \
# 41180                 Cobbs Creek at Alverado Way        33.7484
# 41181  Detention pond on tributary of Rubes Creek        34.0561
# 41182                        Lake Sovereign - CHD        34.1628
# 41201                              Hollow Creek 2        33.3434
# 41203                              Hollow Creek 1        33.3345
# ...                                           ...            ...
# 46295             Ludie Creek at Simpsonwood Park        33.9827
# 46296                        Peachtree Hills Park        33.8180
# 46298                             Ball Mill Creek        33.9787
# 46304          Alapaha River at Naylor Park Beach        30.9254
# 46309              Allatoona Creek - Mason Bridge        34.0217
#
#        site_longitude  site_altitude  bact_detail_rid  ...  hold_end_datetime  \
# 41180        -84.2546     275.440000            43565  ...            00:00.0
# 41181        -84.4971     283.809540            43562  ...            30:00.0
# 41182        -84.5329     273.270000            43547  ...            30:00.0
# 41201        -81.8222      39.512642            44419  ...            55:00.0
# 41203        -81.8534      35.055412            44418  ...            55:00.0
# ...               ...            ...              ...  ...                ...
# 46295        -84.2436     273.910000            49765  ...            15:00.0
# 46296        -84.3783     256.479279            49766  ...            00:00.0
# 46298        -84.3208     268.422729            49829  ...            30:00.0
# 46304        -83.0385      42.410000            49833  ...            30:00.0
# 46309        -84.7086     262.180000            49832  ...            08:00.0
#
#        min_temp max_temp three_M_plate ecoli_idexx fecal_coliform  \
# 41180      35.0     35.5             0         NaN            NaN
# 41181      34.6     35.8             0         NaN            NaN
# 41182      35.0     35.0             0         NaN            NaN
# 41201      34.1     34.6             0         NaN            NaN
# 41203      34.1     34.6             0         NaN            NaN
# ...         ...      ...           ...         ...            ...
# 46295      34.9     35.2             0         NaN            NaN
# 46296      34.5     35.5             0         NaN            NaN
# 46298      34.1     35.5             0         NaN            NaN
# 46304      34.0     35.0             0         NaN            NaN
# 46309      34.1     35.8             0         NaN            NaN
#
#        ecoli_other ecoli_other_unit comments warnings
# 41180          NaN              NaN      NaN      NaN
# 41181          NaN              NaN      NaN      NaN
# 41182          NaN              NaN      NaN      NaN
# 41201          NaN              NaN      NaN      NaN
# 41203          NaN              NaN      NaN      NaN
# ...            ...              ...      ...      ...
# 46295          NaN              NaN      NaN      NaN
# 46296          NaN              NaN      NaN      NaN
# 46298          NaN              NaN      NaN      NaN
# 46304          NaN              NaN      NaN      NaN
# 46309          NaN              NaN      NaN      NaN
#
# [1781 rows x 29 columns]

# %%
variables_to_keep = ["EventDate","SiteID","SiteName","site_latitude","site_longitude","plate_blank","plate_one",
                     "plate_two","plate_three","colony_avg","min_temp","max_temp"]
bacterialData = bacterialData[variables_to_keep]
bacterialData
# Out:
#                 EventDate  SiteID                                    SiteName  \
# 41180 2022-01-01 13:00:00    7342                 Cobbs Creek at Alverado Way
# 41181 2022-01-01 16:30:00     869  Detention pond on tributary of Rubes Creek
# 41182 2022-01-03 09:40:00    6866                        Lake Sovereign - CHD
# 41201 2022-01-05 10:42:00     954                              Hollow Creek 2
# 41203 2022-01-05 11:11:00     953                              Hollow Creek 1
# ...                   ...     ...                                         ...
# 46295 2022-12-19 14:45:00    7337             Ludie Creek at Simpsonwood Park
# 46296 2022-12-19 14:53:00    2033                        Peachtree Hills Park
# 46298 2022-12-20 10:10:00    2368                             Ball Mill Creek
# 46304 2022-12-20 13:30:00    6564          Alapaha River at Naylor Park Beach
# 46309 2022-12-21 12:10:00    6795              Allatoona Creek - Mason Bridge
#
#        site_latitude  site_longitude  plate_blank plate_one plate_two  \
# 41180        33.7484        -84.2546          0.0        11         5
# 41181        34.0561        -84.4971          0.0        22        23
# 41182        34.1628        -84.5329          0.0        24        20
# 41201        33.3434        -81.8222          0.0         2         1
# 41203        33.3345        -81.8534          0.0         1         2
# ...              ...             ...          ...       ...       ...
# 46295        33.9827        -84.2436          0.0         1         1
# 46296        33.8180        -84.3783          0.0         3         2
# 46298        33.9787        -84.3208          0.0         0         1
# 46304        30.9254        -83.0385          0.0         1         1
# 46309        34.0217        -84.7086          0.0         1         0
#
#       plate_three colony_avg  min_temp  max_temp
# 41180          13        966      35.0      35.5
# 41181          19       2133      34.6      35.8
# 41182          26       2333      35.0      35.0
# 41201           1        133      34.1      34.6
# 41203           0        100      34.1      34.6
# ...           ...        ...       ...       ...
# 46295           0         66      34.9      35.2
# 46296           4        300      34.5      35.5
# 46298           3        133      34.1      35.5
# 46304           1        100      34.0      35.0
# 46309           0         33      34.1      35.8
#
# [1781 rows x 12 columns]

# %%
bacterialData = bacterialData.dropna()
bacterialData
# Out:
#                 EventDate  SiteID                                    SiteName  \
# 41180 2022-01-01 13:00:00    7342                 Cobbs Creek at Alverado Way
# 41181 2022-01-01 16:30:00     869  Detention pond on tributary of Rubes Creek
# 41182 2022-01-03 09:40:00    6866                        Lake Sovereign - CHD
# 41201 2022-01-05 10:42:00     954                              Hollow Creek 2
# 41203 2022-01-05 11:11:00     953                              Hollow Creek 1
# ...                   ...     ...                                         ...
# 46295 2022-12-19 14:45:00    7337             Ludie Creek at Simpsonwood Park
# 46296 2022-12-19 14:53:00    2033                        Peachtree Hills Park
# 46298 2022-12-20 10:10:00    2368                             Ball Mill Creek
# 46304 2022-12-20 13:30:00    6564          Alapaha River at Naylor Park Beach
# 46309 2022-12-21 12:10:00    6795              Allatoona Creek - Mason Bridge
#
#        site_latitude  site_longitude  plate_blank plate_one plate_two  \
# 41180        33.7484        -84.2546          0.0        11         5
# 41181        34.0561        -84.4971          0.0        22        23
# 41182        34.1628        -84.5329          0.0        24        20
# 41201        33.3434        -81.8222          0.0         2         1
# 41203        33.3345        -81.8534          0.0         1         2
# ...              ...             ...          ...       ...       ...
# 46295        33.9827        -84.2436          0.0         1         1
# 46296        33.8180        -84.3783          0.0         3         2
# 46298        33.9787        -84.3208          0.0         0         1
# 46304        30.9254        -83.0385          0.0         1         1
# 46309        34.0217        -84.7086          0.0         1         0
#
#       plate_three colony_avg  min_temp  max_temp
# 41180          13        966      35.0      35.5
# 41181          19       2133      34.6      35.8
# 41182          26       2333      35.0      35.0
# 41201           1        133      34.1      34.6
# 41203           0        100      34.1      34.6
# ...           ...        ...       ...       ...
# 46295           0         66      34.9      35.2
# 46296           4        300      34.5      35.5
# 46298           3        133      34.1      35.5
# 46304           1        100      34.0      35.0
# 46309           0         33      34.1      35.8
#
# [1739 rows x 12 columns]

# %%
bacterialData = bacterialData[bacterialData["plate_one"] != "TNTC"]
bacterialData = bacterialData[(bacterialData["plate_two"] != "TNTC") & (bacterialData["plate_two"] != " ")]
bacterialData = bacterialData[bacterialData["plate_three"] != "TNTC"]

# %%
bacterialData["plate_one"] = bacterialData["plate_one"].astype(float)
bacterialData["plate_two"] = bacterialData["plate_two"].astype(float)
bacterialData["plate_three"] = bacterialData["plate_three"].astype(float)
bacterialData["colony_avg"] = bacterialData["colony_avg"].astype(float)

# %%
bacterialData["plate_one"] = bacterialData["plate_one"] * 100
bacterialData["plate_two"] = bacterialData["plate_two"] * 100
bacterialData["plate_three"] = bacterialData["plate_three"] * 100

# %%
bacterialData
# Out:
#                 EventDate  SiteID                                    SiteName  \
# 41180 2022-01-01 13:00:00    7342                 Cobbs Creek at Alverado Way
# 41181 2022-01-01 16:30:00     869  Detention pond on tributary of Rubes Creek
# 41182 2022-01-03 09:40:00    6866                        Lake Sovereign - CHD
# 41201 2022-01-05 10:42:00     954                              Hollow Creek 2
# 41203 2022-01-05 11:11:00     953                              Hollow Creek 1
# ...                   ...     ...                                         ...
# 46295 2022-12-19 14:45:00    7337             Ludie Creek at Simpsonwood Park
# 46296 2022-12-19 14:53:00    2033                        Peachtree Hills Park
# 46298 2022-12-20 10:10:00    2368                             Ball Mill Creek
# 46304 2022-12-20 13:30:00    6564          Alapaha River at Naylor Park Beach
# 46309 2022-12-21 12:10:00    6795              Allatoona Creek - Mason Bridge
#
#        site_latitude  site_longitude  plate_blank  plate_one  plate_two  \
# 41180        33.7484        -84.2546          0.0     1100.0      500.0
# 41181        34.0561        -84.4971          0.0     2200.0     2300.0
# 41182        34.1628        -84.5329          0.0     2400.0     2000.0
# 41201        33.3434        -81.8222          0.0      200.0      100.0
# 41203        33.3345        -81.8534          0.0      100.0      200.0
# ...              ...             ...          ...        ...        ...
# 46295        33.9827        -84.2436          0.0      100.0      100.0
# 46296        33.8180        -84.3783          0.0      300.0      200.0
# 46298        33.9787        -84.3208          0.0        0.0      100.0
# 46304        30.9254        -83.0385          0.0      100.0      100.0
# 46309        34.0217        -84.7086          0.0      100.0        0.0
#
#        plate_three  colony_avg  min_temp  max_temp
# 41180       1300.0       966.0      35.0      35.5
# 41181       1900.0      2133.0      34.6      35.8
# 41182       2600.0      2333.0      35.0      35.0
# 41201        100.0       133.0      34.1      34.6
# 41203          0.0       100.0      34.1      34.6
# ...            ...         ...       ...       ...
# 46295          0.0        66.0      34.9      35.2
# 46296        400.0       300.0      34.5      35.5
# 46298        300.0       133.0      34.1      35.5
# 46304        100.0       100.0      34.0      35.0
# 46309          0.0        33.0      34.1      35.8
#
# [1729 rows x 12 columns]

# %%
bacterialData["E Coli Colony Average Threat Level"] = pd.cut(bacterialData['colony_avg'], 
                        bins=[-1, 100, 235, 410,max(bacterialData['colony_avg'])],  # Define numeric ranges
                        labels=['Rarely Unsafe', 'Tends to be Unsafe','Sometimes Unsafe','Often Unsafe'])

# %%
import numpy as np

bacterialDataSites = bacterialData.groupby("SiteName").agg({
    "SiteID": "min",
    "EventDate": "mean",
    "colony_avg": lambda x: x.mode().iloc[0] if not x.mode().empty else np.nan,
    "E Coli Colony Average Threat Level": lambda x: x.mode().iloc[0] if not x.mode().empty else np.nan,
    "site_latitude": "min",
    "site_longitude": "min"
}).reset_index()

# %%
bacterialDataSites
# Out:
#                                               SiteName  SiteID  \
# 0                               Alapaha River - SR 203    7085
# 1                   Alapaha River at Naylor Park Beach    6564
# 2    Alapaha River at State Road 32 near Irwinville...    7055
# 3       Alapaha River at State Road 35 near Tifton, GA    7094
# 4              Alapahoochee Riv. at Antioch Rd/J'frank    7053
# ..                                                 ...     ...
# 407                                     sherwood creek    7208
# 408                  tributary of Little Suwanne Creek    7348
# 409                          tributary to Canton Creek    2473
# 410                  unnamed tributary to Etowah River    2937
# 411                  up stream Trib of Peachtree Creek    6932
#
#                         EventDate  colony_avg  \
# 0   2022-05-09 16:12:30.000000000       133.0
# 1   2022-09-26 13:48:20.000000000         0.0
# 2   2022-06-06 10:50:00.000000000         0.0
# 3   2022-06-08 09:35:00.000000000       133.0
# 4   2022-03-30 15:40:00.000000000        33.0
# ..                            ...         ...
# 407 2022-04-17 11:53:04.615384576        66.0
# 408 2022-08-18 12:55:00.000000000       133.0
# 409 2022-07-08 22:57:20.000000000        33.0
# 410 2022-08-26 07:32:24.000000000         0.0
# 411 2022-06-13 03:24:45.000000000       266.0
#
#     E Coli Colony Average Threat Level  site_latitude  site_longitude
# 0                   Tends to be Unsafe        31.3756        -82.2887
# 1                        Rarely Unsafe        30.9254        -83.0385
# 2                        Rarely Unsafe        31.6312        -83.4178
# 3                   Tends to be Unsafe        31.5327        -83.3989
# 4                        Rarely Unsafe        30.6733        -83.1049
# ..                                 ...            ...             ...
# 407                 Tends to be Unsafe        34.1078        -83.8994
# 408                 Tends to be Unsafe        34.0347        -84.0074
# 409                 Tends to be Unsafe        34.2321        -84.4906
# 410                      Rarely Unsafe        34.2412        -84.4902
# 411                       Often Unsafe        33.8055        -84.4172
#
# [412 rows x 7 columns]

# %%
bacterialDataSites.to_csv("/Users/keerthyrangan/Downloads/bacterialDataSitesCleaned.csv")

# %%
bacterialData = bacterialData.rename(columns={"plate_one": "1st Sample E Coli Colony Count","plate_two":"2nd Sample E Coli Colony Count",
                              "plate_three":"3rd Sample E Coli Colony Count",
                              "colony_avg":"E Coli Colony Average"})
bacterialData = bacterialData.drop(["plate_blank","min_temp","max_temp"],axis=1)
bacterialData
# Out:
#                 EventDate  SiteID                                    SiteName  \
# 41180 2022-01-01 13:00:00    7342                 Cobbs Creek at Alverado Way
# 41181 2022-01-01 16:30:00     869  Detention pond on tributary of Rubes Creek
# 41182 2022-01-03 09:40:00    6866                        Lake Sovereign - CHD
# 41201 2022-01-05 10:42:00     954                              Hollow Creek 2
# 41203 2022-01-05 11:11:00     953                              Hollow Creek 1
# ...                   ...     ...                                         ...
# 46295 2022-12-19 14:45:00    7337             Ludie Creek at Simpsonwood Park
# 46296 2022-12-19 14:53:00    2033                        Peachtree Hills Park
# 46298 2022-12-20 10:10:00    2368                             Ball Mill Creek
# 46304 2022-12-20 13:30:00    6564          Alapaha River at Naylor Park Beach
# 46309 2022-12-21 12:10:00    6795              Allatoona Creek - Mason Bridge
#
#        site_latitude  site_longitude  1st Sample E Coli Colony Count  \
# 41180        33.7484        -84.2546                          1100.0
# 41181        34.0561        -84.4971                          2200.0
# 41182        34.1628        -84.5329                          2400.0
# 41201        33.3434        -81.8222                           200.0
# 41203        33.3345        -81.8534                           100.0
# ...              ...             ...                             ...
# 46295        33.9827        -84.2436                           100.0
# 46296        33.8180        -84.3783                           300.0
# 46298        33.9787        -84.3208                             0.0
# 46304        30.9254        -83.0385                           100.0
# 46309        34.0217        -84.7086                           100.0
#
#        2nd Sample E Coli Colony Count  3rd Sample E Coli Colony Count  \
# 41180                           500.0                          1300.0
# 41181                          2300.0                          1900.0
# 41182                          2000.0                          2600.0
# 41201                           100.0                           100.0
# 41203                           200.0                             0.0
# ...                               ...                             ...
# 46295                           100.0                             0.0
# 46296                           200.0                           400.0
# 46298                           100.0                           300.0
# 46304                           100.0                           100.0
# 46309                             0.0                             0.0
#
#        E Coli Colony Average 1st Single Sample E Coli Threat Level  \
# 41180                  966.0      High Risk for Waterborne Illness
# 41181                 2133.0      High Risk for Waterborne Illness
# 41182                 2333.0      High Risk for Waterborne Illness
# 41201                  133.0         Still in Acceptable Threshold
# 41203                  100.0                      Water Very Clean
# ...                      ...                                   ...
# 46295                   66.0                      Water Very Clean
# 46296                  300.0      High Risk for Waterborne Illness
# 46298                  133.0                      Water Very Clean
# 46304                  100.0                      Water Very Clean
# 46309                   33.0                      Water Very Clean
#
#       2nd Single Sample E Coli Threat Level  \
# 41180      High Risk for Waterborne Illness
# 41181      High Risk for Waterborne Illness
# 41182      High Risk for Waterborne Illness
# 41201                      Water Very Clean
# 41203         Still in Acceptable Threshold
# ...                                     ...
# 46295                      Water Very Clean
# 46296         Still in Acceptable Threshold
# 46298                      Water Very Clean
# 46304                      Water Very Clean
# 46309                      Water Very Clean
#
#       3rd Single Sample E Coli Threat Level E Coli Colony Average Threat Level
# 41180      High Risk for Waterborne Illness     Tends to be UnsafeOften Unsafe
# 41181      High Risk for Waterborne Illness     Tends to be UnsafeOften Unsafe
# 41182      High Risk for Waterborne Illness     Tends to be UnsafeOften Unsafe
# 41201                      Water Very Clean                   Sometimes Unsafe
# 41203                      Water Very Clean                      Rarely Unsafe
# ...                                     ...                                ...
# 46295                      Water Very Clean                      Rarely Unsafe
# 46296      High Risk for Waterborne Illness                   Sometimes Unsafe
# 46298      High Risk for Waterborne Illness                   Sometimes Unsafe
# 46304                      Water Very Clean                      Rarely Unsafe
# 46309                      Water Very Clean                      Rarely Unsafe
#
# [1729 rows x 13 columns]

# %%
bacterialData.to_csv("/Users/keerthyrangan/Downloads/bacterialDataCleaned.csv")
